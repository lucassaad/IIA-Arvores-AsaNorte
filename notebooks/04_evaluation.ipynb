# %% [markdown]
# # 04. Avaliação Estatística e Inferência Visual
#
# Este notebook computa as métricas finais após o treinamento (curvas de Precisão-Revogação, F1-score, Matriz de Confusão e MAP), além de gerar inferência visual qualitativa em imagens não vistas pelo modelo.
#
# **Responsável:** Pessoa 9

# %%
import sys
sys.path.append('..')
import utils
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Avaliação Quantitativa (Métricas do Modelo)

# %%
# Carga de resultados e plotagem de curvas PR / F1-Score

# %% [markdown]
# ## 2. Inferência Qualitativa em Imagens de Teste

# %%
# Função para inferência rápida e plotagem visual das bounding boxes preditas
