# %% [markdown]
# # 03. Treinamento e Fine-Tuning do YOLOv11m no Kaggle
#
# Este notebook executa no Kaggle o download do `dataset_limpo.h5` do Google Drive, realiza a extração direta das imagens/labels na memória RAM (`/dev/shm`), e inicia o treinamento com Transfer Learning congelando o backbone e aplicando data augmentations.
#
# **Responsáveis:** Pessoa 7 (Wallysson) e Pessoa 8 (Celio Eduardo)

# %%
import sys
sys.path.append('..')
import utils
import os
from ultralytics import YOLO

# %% [markdown]
# ## 1. Download do Google Drive & Extração rápida no RAM Disk (Pessoa 7)

# %%
# Exemplo de gdown e extração
# hdf5_path = 'dataset_limpo.h5'
# utils.extrair_hdf5_para_ram(hdf5_path, '/dev/shm/dataset')

# %% [markdown]
# ## 2. Configurações de Regularização e Fine-Tuning do YOLOv11m (Pessoa 8)

# %%
# Configuração do modelo e do treino com backbone congelado (freeze=10)
# model = YOLO('yolov11m.pt')
# model.train(data='data.yaml', epochs=50, freeze=10, patience=10, ...)
